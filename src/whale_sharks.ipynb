# %%
import utilities as util
import preprocessor as prep
import pandas as pd
import folium

# %% [markdown]
# <h1> Whale Sharks - Rhincodon Typus</h1>
#
# <h2>Data:</h2>
#
# link to data:  https://www.movebank.org/cms/webapp?gwt_fragment=page=studies,path=study1153270750
# <br>
# citation:
# Hoffmayer E, et al, B. Schumaker. Whale shark movements in Gulf of Mexico. Funding provided by the International Fund for Animal Welfare, World Wildlife Fund, Defenders of Wildlife, Shared Earth Foundation, Nature Conservancy Texas Chapter, and Louisiana Department of Wildlife and Fisheries (LDWF). Movebank Data Repository.

# %%
full_hurricane_1992 = prep.process_hurricane_txt('C:/Users/Ben/Documents/GitHub/Animal-Motion-for-predictions/data/hurricanes_1992.txt')
whale_sharks = prep.preprocess_whale_sharks('C:/Users/Ben/Documents/GitHub/Animal-Motion-for-predictions/data/whaleSharks/Whale_Sharks_refined.csv')
# Out:
# c:\Users\Ben\Documents\GitHub\Animal-Motion-for-predictions\src\preprocessor.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lat_column.iloc[i] = lat
# c:\Users\Ben\Documents\GitHub\Animal-Motion-for-predictions\src\preprocessor.py:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lon_column.iloc[i] = lon

# %%
g_p = util.get_cross_points(full_hurricane_1992,whale_sharks,450)
g_p
# Out:
# c:\Users\Ben\Documents\GitHub\Animal-Motion-for-predictions\src\utilities.py:165: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   good_pnts = good_pnts.append(row, ignore_index= True)
# c:\Users\Ben\Documents\GitHub\Animal-Motion-for-predictions\src\utilities.py:165: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   good_pnts = good_pnts.append(row, ignore_index= True)
# c:\Users\Ben\Documents\GitHub\Animal-Motion-for-predictions\src\utilities.py:165: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   good_pnts = good_pnts.append(row, ignore_index= True)
# ...

# %%
print(g_p['name'].unique())
print(g_p['event_name'].unique())
# Out:
# ['"128783"' '"128784"' '"101199"' '"128787"']
# ['BILL4' 'DOLLY4' 'EIGHT2']

# %%
Crossed_points = make_cp_dict(g_p)
Crossed_points['BILL4']['animals']['"128784"']['after event']
# Out:
# "128783"
# "128784"
# "101199"
# "128787"
#          event-id  visible       date  longitude   latitude      name  year  \
# 2853  14948488774     True 2015-06-22  -94.43411  24.581364  "128784"  2015
# 2854  14948488775     True 2015-06-23  -94.53200  24.424000  "128784"  2015
#
#           depth          species
# 2853 -59.560341  Rhincodon Typus
# 2854 -56.486153  Rhincodon Typus
